# %% [markdown]
# # Tuples

# %% [markdown]
# ## Tuple creation

# %%
tup1 = ()

# %%
type(tup1)
# Out:
# tuple

# %%
len(tup1)
# Out:
# 0

# %%
tup2 = (10,20,30) # tuple of integers

# %%
tup3 = (10.88,67.76,99.22) # tuple of float numbers

# %%
tup4 = ('one', 'two', 'three', 'four') # tuple of strings

# %%
tup5 = ('Shoaib', 22, (20,10), (120, 80)) # nested tuples

# %%
tup6 = (10, 'Shoaib', 87.55) # tuple of mixed data types

# %%
tup7 = ('Shoaib', 22, [50, 100], [150, 90], {'John', 'Ben'}, (99,33,44))

# %%
len(tup7)
# Out:
# 6

# %% [markdown]
# ## Tuple Indexing:

# %%
tup2
# Out:
# (10, 20, 30)

# %%
tup2[0]
# Out:
# 10

# %%
tup4[0]
# Out:
# 'one'

# %%
tup4[0][0] # nested indexing - returns the first character of the first index element
# Out:
# 'o'

# %%
tup2[0][0] # works only with strings
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 tup2[0][0] # works only with strings
#
# TypeError: 'int' object is not subscriptable

# %%
tup4[-1]
# Out:
# 'four'

# %%
tup5
# Out:
# ('Shoaib', 22, (20, 10), (120, 80))

# %%
tup5[-1]
# Out:
# (120, 80)

# %% [markdown]
# ## Tuple Slicing

# %%
tup4
# Out:
# ('one', 'two', 'three', 'four')

# %%
tup4[1:4]
# Out:
# ('two', 'three', 'four')

# %%
tup2
# Out:
# (10, 20, 30)

# %%
tup2[0:]
# Out:
# (10, 20, 30)

# %%
tup2[:2]
# Out:
# (10, 20)

# %%
tup4[1::2]
# Out:
# ('two', 'four')

# %%
mytuple = ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple[0:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[2:5]
# Out:
# ('three', 'four', 'five')

# %%
mytuple[:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[:2]
# Out:
# ('one', 'two')

# %%
mytuple[-3:]
# Out:
# ('six', 'seven', 'eight')

# %%
mytuple[-2:]
# Out:
# ('seven', 'eight')

# %%
mytuple[-1]
# Out:
# 'eight'

# %%
mytuple[:]
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %% [markdown]
# ## remove and change items in tuple

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple.append(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 mytuple.append(10)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
mytuple.remove('one')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 mytuple.remove('one')
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %% [markdown]
# + tuple is immutable, once created, it cannot be changed nor be destroyed

# %%
del mytuple # this function will work becaue we are deleting the whole tuple

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %% [markdown]
# ## Loops in tuple

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
for i in mytuple:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(mytuple):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %% [markdown]
# ## Tuple Membership

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
'one' in mytuple
# Out:
# True

# %%
'three' in mytuple
# Out:
# True

# %%
'ten' in mytuple
# Out:
# False

# %%
if 'three' in mytuple:
    print('Three exists in the tuple')
else:
    print('Three does not exist in the tuple')
# Out:
# Three exists in the tuple

# %%
if 'eleven' in mytuple:
    print('eleven belongs to the tuple')
else:
    print('eleven does not belong to the tuple')
# Out:
# eleven does not belong to the tuple

# %% [markdown]
# ## Index position

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple.index('one')
# Out:
# 0

# %%
mytuple.index('five')
# Out:
# 4

# %%
mytuple1 = ('one', 'two', 'three', 'four', 'one', 'one', 'two', 'three')

# %%
mytuple1.index('two')
# Out:
# 1

# %%
mytuple1.index('one')
# Out:
# 0

# %% [markdown]
# ## Sorting

# %%
mytuple2 = (44, 55, 66, 77, 88, 12, 6, 67)

# %%
sorted(mytuple2)
# Out:
# [6, 12, 44, 55, 66, 77, 88]

# %%
sorted(mytuple2, reverse = True)
# Out:
# [88, 77, 66, 55, 44, 12, 6]

# %%
mytuple1
# Out:
# ('one', 'two', 'three', 'four', 'one', 'one', 'two', 'three')

# %% [markdown]
# ## Count function

# %%
mytuple1
# Out:
# ('one', 'two', 'three', 'four', 'one', 'one', 'two', 'three')

# %%
mytuple1.count('one')
# Out:
# 3

# %%
mytuple1.count('three')
# Out:
# 2

# %%
# returns the number of occurenccs of the given item in the list.
