# %% [markdown]
# # List Data Sctucture

# %%
# list
l = [] # this is an empty list
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %% [markdown]
# ### functions of list:
# + after defining the list, like we did l = [] in above, we can now perform multiple functions on l i.e, list
# + after writing ' l. ' press tab and then we can see the list functions
# +

# %%
l.append(10) # append function lets us add values in the existing list l

# %%
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %%
l.append(20,30,40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 l.append(20,30,40)
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
# .append can take only one argument at a time

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l.append(10)
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
# we can add duplicate values in the list

# %%
li = [10, 3.5, True, 1+2j, 'welcome']

# %%
li
# Out:
# [10, 3.5, True, (1+2j), 'welcome']

# %%
# list can take multiple data types

# %%
# nested list
li.append([1, 2, 3])
li
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
print(l)
print(li)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
# if we are stuck, restart the kernel

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
# we can copy the attributes of one list to another with the help of copy function. Press tab to see it
l3 = l.copy()

# %%
l3
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(l)
print(li)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]
# [10, 20, 30, 40, 50, 10]

# %%
# checking if l is equal to l3
l == l3
# Out:
# True

# %%
# checking if the lenght of l is equal to of l3
len(l) == len(l3)
# Out:
# True

# %%
# checking if the id of l is equal to of id of l3
id(l) == id(l3)
# Out:
# False

# %%
id(l) != id(l3)
# Out:
# True

# %%
print(id(l))
print(id(l3))
# Out:
# 2385910780736
# 2385918308672

# %%
print(l)
print(li)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]
# [10, 20, 30, 40, 50, 10]

# %%
# not clearing the l3 with clear function
l3.clear()

# %%
l3
# Out:
# []

# %%
# clear function eliminaters the arguments in the list but does not delete the list

# %%
print(l)
print(li)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]
# []

# %%
# now, deleting the l3 compmetely with del function
del l3

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
# l3 is now completely deleted

# %%
print(l)
print(li)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
print(l)
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
# using the count functon on list l
# count function counts the occurences of the givern value argument

l.count(10)
# Out:
# 2

# %%
l.count(20)
# Out:
# 1

# %%
l.count(30)
# Out:
# 1

# %%
print(l)
print(li)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
# using the extend function
l.extend(li)

# %%
l
# Out:
# [10,
#  20,
#  30,
#  40,
#  50,
#  10,
#  10,
#  3.5,
#  True,
#  (1+2j),
#  'welcome',
#  [1, 2, 3],
#  10,
#  3.5,
#  True,
#  (1+2j),
#  'welcome',
#  [1, 2, 3],
#  10,
#  3.5,
#  True,
#  (1+2j),
#  'welcome',
#  [1, 2, 3]]

# %%
a1 = [1, 2, 3]
b1 = [4, 5, 6]

# %%
a1.extend(b1)

# %%
a1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(a1)
print(b1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [4, 5, 6]

# %%
print(l)
print(li)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 3.5, True, (1+2j), 'welcome', [1, 2, 3], 10, 3.5, True, (1+2j), 'welcome', [1, 2, 3], 10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
# using the index functon
# it specifies the index location of the given value

l.index(20)

# this means that the value 20 is located on the 1 index position
# Out:
# 1

# %%
li.index(1+2j)
# Out:
# 3

# %%
li.index('welcome')
# Out:
# 4

# %%
li[:]
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
 li[3]
# Out:
# (1+2j)

# %%
li[5]
# Out:
# [1, 2, 3]

# %%
li[:3]
# Out:
# [10, 3.5, True]

# %%
li[3:]
# Out:
# [(1+2j), 'welcome', [1, 2, 3]]

# %%
li[-3]
# Out:
# (1+2j)

# %%
li[0:5:2]
# Out:
# [10, True, 'welcome']

# %%
li
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
li[:-3]
# Out:
# [10, 3.5, True]

# %%
li[-3:]
# Out:
# [(1+2j), 'welcome', [1, 2, 3]]

# %%
li
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
li[::-1]
# Out:
# [[1, 2, 3], 'welcome', (1+2j), True, 3.5, 10]

# %%
li[::-2]
# Out:
# [[1, 2, 3], (1+2j), 3.5]

# %%
li[4]
# Out:
# 'welcome'

# %%
# nested indexing

print(li[4][0])
print(li[4][1])
print(li[4][2])
print(li[4][3])
print(li[4][4])
print(li[4][5])
print(li[4][6])
print(li[4][7])
# Out:
# w
# e
# l
# c
# o
# m
# e
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[90], line 10
#       8 print(li[4][5])
#       9 print(li[4][6])
# ---> 10 print(li[4][7])
#
# IndexError: string index out of range

# %%
li
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
li[0] = 100

# %%
li
# Out:
# [100, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]

# %%
li[0]
# Out:
# 100

# %%
li[0] = 10

# %%
li
# Out:
# [10, 3.5, True, (1+2j), 'welcome', [1, 2, 3]]
