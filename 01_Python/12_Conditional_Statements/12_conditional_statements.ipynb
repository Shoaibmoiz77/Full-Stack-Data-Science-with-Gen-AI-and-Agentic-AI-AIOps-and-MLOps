# %% [markdown]
# # Conditional Statements:
# - if
# - else
# - nested if
# - if elif else

# %%
if True:
    print('Data Science')
# Out:
# Data Science

# %%
if False:
    print('Data Science')
print('bye for now')
# Out:
# bye for now

# %%
if True:
    print('Data Science')
print('bye for now')
# Out:
# Data Science
# bye for now

# %%
## else:

# %%
if True:
    print('Data Science')
else:
    print('bye for now')
# Out:
# Data Science

# %%
if False:
    print('Data Science Job')
else:
    print('no job')
# Out:
# no job

# %%
# with variables:
x = 4
r = x % 2

if r == 0:
    print('Even number')
# Out:
# Even number

# %%
x = 5
r = x % 2
if r == 0:
    print('Even Number')

# %%
x = 5
r = x % 2
if r != 0:
    print('Odd Number')
# Out:
# Odd Number

# %%
x = 5
r = x % 2
if r == 0:
    print('Even Number')
print('odd number')
# Out:
# odd number

# %%
x = 4
r = x % 2
if r == 0:
    print('Even Number')
print('odd number')
# Out:
# Even Number
# odd number

# %%
## Multiple if Statements use:

# %%
x = 9
r = x % 2
if r == 0:
    print('Even number')
if r == 1:
    print('odd number')
# Out:
# odd number

# %%
## if and else usage:

# %%
x = 8
r = x % 2
if r == 0:
    print('Even Number')
else:
    print('Odd Number')
# Out:
# Even Number

# %%
x = 9
r = x % 2
if r != 0:
    print('Odd Number')
else:
    print('Even Number')
# Out:
# Odd Number

# %%
## Nested if  statement use:

# %%
x = 3
r = x % 2
if r == 0:
    print( 'Even Number')
    if x > 5:
        print('greater number')
else:
    print('odd number')
# Out:
# odd number

# %%
x = 4
r = x % 2
if r == 0:
    print( 'Even Number')
    if x > 5:
        print('greater number')
else:
    print('odd number')
# Out:
# Even Number

# %%
## Nested if else statement use case:

# %%
x = 4
r = x % 2
if r == 0:
    print('Even number')
    if x > 5:
        print('greater number')
    else:
        print('lesser number')
else:
    print('Odd number')
# Out:
# Even number
# lesser number

# %%
x = 13
r = x % 2
if r == 0:
    print('Even number')
    if x > 5:
        print('greater number')
    else:
        print('lesser number')
else:
    print('odd number')
# Out:
# odd number

# %%
x = 6
r = x % 2
if r == 0:
    print('Even number')
    if x > 5:
        print('greater number')
    else:
        print('lesser number')
else:
    print('odd number')
# Out:
# Even number
# greater number

# %%
## Multiple if statements:

# %%
x = 3
if x == 1:
    print('one')
if x == 2:
    print('two')
if x == 3:
    print('three')
if x == 4:
    print('four')
# Out:
# three

# %%
## elif statements usage:

# %%
x = 1
if x == 1:
    print('one')
elif x == 2:
    print('two')
elif x == 3:
    print('three')
elif x == 4:
    print('four')
# Out:
# one

# %%
## if, elif and else statements usage:

# %%
x = 5
if x == 1:
    print('one')
elif x == 2:
    print('two')
elif x == 3:
    print('three')
elif x == 4:
    print('four')
else:
    print('number not found')
# Out:
# number not found

# %%
age = 19
if age > 18: print('Eligible to vote')
# Out:
# Eligible to vote
