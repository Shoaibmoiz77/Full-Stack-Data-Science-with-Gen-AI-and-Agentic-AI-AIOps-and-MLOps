# %% [markdown]
# # Seaborn

# %% [markdown]
# - First, we will upload the data from the previous file
# - then we will perform the tasks of seaborn library

# %%
# working on the same data as of file 16.1 and 16.2

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = 6,2

import warnings
warnings.filterwarnings('ignore')

# %%
df = df = pd.read_excel(r"C:\Users\shoai\Downloads\data.xlsx")

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
vis1= sns.distplot(df['InternetUsers']) # this is univariate analysis

# %%
# plotting the graph with one variable is called univariate analysis

# %%
vis2 = sns.displot(df['InternetUsers'])

# %%
vis2 = sns.displot(df['InternetUsers'], bins = 15)

# %%
# the vertical blue bars are called bins, bins = 15 generates 15 bins

# %%
vis2 = sns.displot(df['InternetUsers'], bins = 10)

# %%
vis4 = sns.boxplot(data = df, x = 'InternetUsers')

# %%
vis5 = sns.lmplot(data = df, x = 'InternetUsers', y = 'BirthRate')

# %%
vis6 = sns.lmplot(data = df, x = 'InternetUsers', y = 'BirthRate', fit_reg = False)

# %%
# the above functon removes the linear regression line from the graph

# %%
vis6 = sns.lmplot(data = df, x = 'InternetUsers', y = 'BirthRate', fit_reg = True)

# %%
vis8 = sns.lmplot(data = df, x = 'InternetUsers', y = 'BirthRate', fit_reg = False,
                  hue = 'IncomeGroup')

# %%
vis8 = sns.lmplot(data = df, x = 'InternetUsers', y = 'BirthRate', fit_reg = True,
                  hue = 'IncomeGroup')
