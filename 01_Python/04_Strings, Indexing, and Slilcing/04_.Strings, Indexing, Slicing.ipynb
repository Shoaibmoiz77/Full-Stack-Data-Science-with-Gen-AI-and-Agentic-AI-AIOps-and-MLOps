# %% [markdown]
# # Strings

# %% [markdown]
# ## Strings Creation

# %%
s = welcome
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 s = welcome
#       2 s
#
# NameError: name 'welcome' is not defined

# %%
# strings are always declared in quotation marks
# string with single quotation
s = 'weclome'
s
# Out:
# 'weclome'

# %%
# string with double quotation
s1 = "welcome everyone"
s1
# Out:
# 'welcome everyone'

# %%
# string with triple quotation
s2 = ''' welcome world '''
s2
# Out:
# ' welcome world '

# %%
s3 = 'welcome to the world
      where people with different
      ideas live together'
s3
# Out:
#   Cell In[14], line 1
#     s3 = 'welcome to the world
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s4 = "welcome to the world
       where pepople share their
       beautiful ideas"
s4
# Out:
#   Cell In[16], line 1
#     s4 = "welcome to the world
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s4 = ''' welocome everyone to the world
         where curiosity leads to the 
         inventon of ideas and also
         solving problems'''
s4
# Out:
# ' welocome everyone to the world\n         where curiosity leads to the \n         inventon of ideas and also\n         solving problems'

# %% [markdown]
# ## some operations and functions with strings

# %%
mystr_1 = 'health '
mystr_1 = mystr_1*2
mystr_1
# Out:
# 'health health '

# %%
mystr_1 = mystr_1*5
mystr_1
# Out:
# 'health health health health health health health health health health '

# %% [markdown]
# ## string indexing

# %% [markdown]
# ### forward indexing

# %%
si = 'welcome'
si
# Out:
# 'welcome'

# %%
si[0] #string index always starts with 0
# Out:
# 'w'

# %%
si[4]
# Out:
# 'o'

# %%
si[10] # si index size is n-1 that is 6
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 si[10]
#
# IndexError: string index out of range

# %% [markdown]
# ### backward indexing

# %% [markdown]
# This index starts with the right side and the starting index is -1

# %%
si
# Out:
# 'welcome'

# %%
si[-1] # that is the last word in the si
# Out:
# 'e'

# %%
si[-3]
# Out:
# 'o'

# %%
si[-7]
# Out:
# 'w'

# %%
si[-10] # the length of the backward index is -7
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 si[-10]
#
# IndexError: string index out of range

# %%
si[-8] # the length of the backward index is -7
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 si[-8]
#
# IndexError: string index out of range

# %% [markdown]
# # String Slicing

# %% [markdown]
# It is used and denoted by the symbol,
# It is heavily used in LLMs,
# It starts with 0 and ends with n-1 range,

# %% [markdown]
# ## Forward Slicing

# %%
si
# Out:
# 'welcome'

# %%
si[:] # this gives the overall index of the string range
# Out:
# 'welcome'

# %%
si[1:]
# Out:
# 'elcome'

# %%
si[0:7]
# Out:
# 'welcome'

# %%
si[0:4]
# Out:
# 'welc'

# %%
si[0:7]
# Out:
# 'welcome'

# %%
si[4:5]
# Out:
# 'o'

# %%
si[:7]
# Out:
# 'welcome'

# %%
si[0:]
# Out:
# 'welcome'

# %%
si[0:10]
# Out:
# 'welcome'

# %%
si[0:100]
# Out:
# 'welcome'

# %% [markdown]
# ## Backward Slicing

# %%
si[:-1]
# Out:
# 'welcom'

# %%
si[-1:] # retrieves the last 1 charactter of the string literal
# Out:
# 'e'

# %%
si[-6:] # gives the last six characters of the string
# Out:
# 'elcome'

# %%
si[:-6] # neglets the last six characters of the string
# Out:
# 'w'

# %%
si[:-7]
# Out:
# ''

# %% [markdown]
# ### updating and deleting a string

# %%
str1 = 'hello python'
str1
# Out:
# 'hello python'

# %%
str1[0:] = 'python' # string once created cannot be updated
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 str1[0:] = 'python'
#
# TypeError: 'str' object does not support item assignment

# %%
del str1

# %%
print(str1) # the string str1 is deleted and cannot be retrieved
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 print(str1)
#
# NameError: name 'str1' is not defined

# %% [markdown]
# ### String concatination

# %%
s1 = 'shoaib'
s2 = 'moiz'
s3 = s1 + s2
s3
# Out:
# 'shoaibmoiz'

# %%
print(s3)
# Out:
# shoaibmoiz
