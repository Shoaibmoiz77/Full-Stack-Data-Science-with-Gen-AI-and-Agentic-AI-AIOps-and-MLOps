# %% [markdown]
# # Integer

# %%
i = 5
i
# Out:
# 5

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140714710705192

# %%
age = 22
age
# Out:
# 22

# %%
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# # Float

# %%
f = 7.7
f
# Out:
# 7.7

# %%
type(f)
# Out:
# float

# %%
id(f)
# Out:
# 2171641594480

# %%
print(i)
print(type(i))
print(id(i))
# Out:
# 5
# <class 'int'>
# 140714710705192

# %% [markdown]
# # Bool

# %%
b = true # true --> True, since it is a reserved word
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 b = true
#
# NameError: name 'true' is not defined

# %%
b = True
b
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
b1 = False
b1
# Out:
# False

# %%
type(b1)
# Out:
# bool

# %%
# variables having the same memory locaton
p = 10
q = 10

# %%
p,q = 10, 10

# %%
print(id(p))
print(id(q))
# Out:
# 140714710705352
# 140714710705352

# %% [markdown]
# ## Bool operations

# %%
p = p + 10
p
# Out:
# 20

# %%
print(p)
print(q)
# Out:
# 20
# 10

# %%
print(id(p))
print(id(q))
# Out:
# 140714710705672
# 140714710705352

# %%
print(b)
print(b1)
# Out:
# True
# False

# %%
b
# Out:
# True

# %%
b1
# Out:
# False

# %%
True + False
# Out:
# 1

# %%
True - False
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
True / False # since anyting by zero is always undefined or infinity
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
False / True
# Out:
# 0.0

# %%
False // True # for integer value
# Out:
# 0

# %% [markdown]
# # Complex

# %%
c = 10 + 20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c1 = 20 - 30j
c1
# Out:
# (20-30j)

# %%
print(c)
print(c1)
# Out:
# (10+20j)
# (20-30j)

# %%
# to print the real part from c
print(c)
print(c.real)
# Out:
# (10+20j)
# 10.0

# %%
# to print the imaginary part from c
print(c)
print(c.imag)
# Out:
# (10+20j)
# 20.0

# %%
# complex addition
c + c1
# Out:
# (30-10j)
