# %% [markdown]
# # syntax:
# variable_name = value

# %%
v = 5
v
# Out:
# 5

# %% [markdown]
# # Rules to define a Pyton Variable:

# %%
# 1. a variable name must start with a name(string) or an underscore(_)
name = 'shoaib'

# %%
_name = 'shoaib'

# %%
1name = 'shoaib'
# Out:
#   Cell In[4], line 1
#     1name = 'shoaib'
#     ^
# SyntaxError: invalid decimal literal

# %%
# 2. a variable can contain letters, numbers, and underscore
student = 'shoaib'

# %%
student_name = 'shoaib'

# %%
student_name123 = 'shoaib'

# %%
# 3. a variable name cannot contaion spaces
student name = 'shoaib'
# Out:
#   Cell In[10], line 2
#     student name = 'shoaib'
#             ^
# SyntaxError: invalid syntax

# %%
student_name = 'shoaib'

# %%
# 4. special characters are not allowed while variable declaration
student@name = 'shoaib'
# Out:
#   Cell In[12], line 2
#     student@name = 'shoaib'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
college-name = 'osmania university'
# Out:
#   Cell In[13], line 1
#     college-name = 'osmania university'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# 5. variable names are case sensitive
name = 'shoaib'
Name = 'mohammed'
print(name)
print(Name)
# Out:
# shoaib
# mohammed

# %%
# 6. python keywords cannot be used as variables
import keyword
(keyword.kwlist)
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
if = 23
# Out:
#   Cell In[18], line 1
#     if = 23
#        ^
# SyntaxError: invalid syntax

# %%
IF = 23

# %% [markdown]
# # python variable = value = datatype

# %%
#integer
i = 5
type(i)
# Out:
# int

# %%
#float
f = 6.6
type(f)
# Out:
# float

# %%
s = 'it'
type(s)
# Out:
# str

# %%
pass_out = True
print(pass_out)
print(type(pass_out))
# Out:
# True
# <class 'bool'>
